# %% [markdown]
# # HER Training Demo
#
# This notebook demonstrates how to train a HER agent on the BitFlip environment.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from src.envs import EnvironmentFactory
from src.agents.her_agent import HERAgent
from src.utils.logger import setup_logger

# Setup logging
logger = setup_logger("HER_Demo")
logger.info("Starting HER training demo")
